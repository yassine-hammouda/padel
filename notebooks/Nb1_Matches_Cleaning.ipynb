# %%
import sys
# !{sys.executable} -m pip install psycopg2-binary sqlalchemy --no-cache-dir

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:123456@localhost:5432/dw_padel")

conn = engine.connect()
print("Connexion réussie !")
conn.close()
# Out:
# Connexion réussie !

# %%
tables = pd.read_sql("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public'
    ORDER BY table_name
""", engine)

print(tables.to_string())
# Out:
#                table_name
# 0               dim_brand
# 1                dim_date
# 2            dim_location
# 3              dim_player
# 4             dim_product
# 5               dim_round
# 6             dim_sponsor
# 7                dim_team
# 8                dim_tour
# 9          dim_tournament
# 10             fact_match
# 11      fact_player_stats
# 12       fact_sponsorship
# 13  fact_tournament_stats

# %%
import os

# Voir ce qui est dans le dossier data
for f in os.listdir('../data'):
    print(f)
# Out:
# anomaly_results_tournaments.csv
# clean_accessoires.csv
# clean_brand_market_share.csv
# clean_chaussures.csv
# clean_dim_ranking.csv
# clean_fip_titles.csv
# clean_matches.csv
# clean_players.csv
# clean_players_equipment.csv
# clean_players_social.csv
# clean_players_titles.csv
# clean_rackets.csv
# clean_racket_performance.csv
# clean_seasons.csv
# clean_sponsorship.csv
# clean_top1_ranking.csv
# clean_top_tournaments.csv
# clean_tournaments.csv
# clean_tournaments_social.csv
# tournaments_clustered.csv

# %%
df = pd.read_csv('../data/clean_matches.csv')
print("Shape:", df.shape)
print("\nColonnes:", df.columns.tolist())
print("\nValeurs manquantes:\n", df.isnull().sum())
df.head()
# Out:
# Shape: (1260, 16)
#
# Colonnes: ['id', 'name', 'category', 'round', 'round_name', 'index', 'played_at', 'status', 'score', 'winner', 'duration_minutes', 'players', 'competition_source', 'season_year', 'tournament_name', 'court']
#
# Valeurs manquantes:
#  id                      0
# name                   82
# category                0
# round                   0
# round_name              0
# index                   0
# played_at               0
# status                  0
# score                 375
# winner                116
# duration_minutes      624
# players                 0
# competition_source      0
# season_year             0
# tournament_name         0
# court                 699
# dtype: int64
#      id                               name category  round  round_name  index  \
# 0  6987     Tapia/Coello - Chingotto/Galan      men      1      Finals      0
# 1  7018    Triay/Brea - Fernandez/Gonzalez    women      1      Finals      0
# ...
